# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu = 0
std = 0.2
x = np.linspace(start=-4, stop=4, num=100)
y = list(range(100))
plt.plot(x, y)
plt.show()

# %%
plt.figure()
x = [1,2,7]
y = [4,5,6]
plt.plot(x,y)
plt.show()
